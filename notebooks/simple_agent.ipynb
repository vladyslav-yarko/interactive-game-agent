# %%
#NOTE: simple agent is just test agent to test architecture before using complex interactive game agent

import os

# %%
# Make required imports

os.chdir("..")

from src.core.agents.simple import simple_agent
from src.core.graphs.simple import simple_graph
from src.core.schemas.simple import SimpleStateInput

# %%
result = await simple_agent.run(
    input=SimpleStateInput(name="Vladyslav")
)
result
# Out:
# {'persona': 'Vladyslav is glad'}

# %%
graph_image = simple_graph.display()

graph_image
